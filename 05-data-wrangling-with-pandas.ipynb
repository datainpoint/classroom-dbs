# %% [markdown]
# # Data Visualization with Modern Data Science
#
# > Data Wrangling with Pandas
#
# Kuo, Yao-Jen

# %%
import pandas as pd
import requests

# %% [markdown]
# # TL; DR
#
# > In this lecture, we will talk about how to build a Python environment for analytics locally and essential data wrangling skills in `pandas`.

# %% [markdown]
# ## Building an Environment for Analytics Locally

# %% [markdown]
# ## There are tons of ways building your local environments, just like ice cream flavors
#
# ![](https://media.giphy.com/media/H1KLQt3RT0sHm/giphy.gif)
#
# Source: <https://giphy.com/>

# %% [markdown]
# ## Let's write a simple conditional
#
# - If we are not using `Windows`(`Linux`/`macOS`),then go with `conda` and `pip`
# - If we are using `Windows`
#     - and already installed either `Anaconda` or `Miniconda`, then go with `conda` and `pip`
#     - and neither `Anaconda` nor `Miniconda` is installed, then go with `venv` and `pip`

# %% [markdown]
# ## What is `Anaconda`?
#
# > Anaconda is a data science toolkit with over 20 million users worldwide, it is the easiest way to perform Python/R data science and machine learning on a single machine. Developed for solo practitioners, it is the toolkit that equips you to work with thousands of open-source packages and libraries.
#
# Source: <https://www.anaconda.com/>

# %% [markdown]
# ## `Anaconda`, simply put, is the combination of
#
# - Python interpreter
# - Python standard libraries
# - Popular data science libraries
# - Environment manager
# - Package managers
# - Integrated Development Environments
# - ...a lot more

# %% [markdown]
# ## That's why it is called "anaconda", cuz it is a lot bigger than a regular "python"
#
# - [Anacondas: The Hunt for the Blood Orchid (2004)](https://www.imdb.com/title/tt0366174)
# - [Anacondas: Mystery Solved (2017)](https://www.imdb.com/title/tt7704056)
#
# Source: <https://www.imdb.com/>

# %% [markdown]
# ## What is `Miniconda`?
#
# > Miniconda is a small, bootstrap version of Anaconda that includes only conda, Python, the packages they depend on, and a small number of other useful packages, including pip, zlib and a few others.
#
# Source: <https://docs.conda.io/en/latest/index.html>

# %% [markdown]
# ## `Miniconda`, simply put, is the combination of
#
# - Python interpreter
# - Python standard libraries
# - Environment manager
# - Package managers

# %% [markdown]
# ## What is `conda`?
#
# > Conda is an open-source package management system and environment management system that runs on Windows, macOS, and Linux. Conda quickly installs, runs, and updates packages and their dependencies. Conda easily creates, saves, loads, and switches between environments on your local computer. It was created for Python programs but it can package and distribute software for any language.
#
# Source: <https://docs.conda.io/projects/conda/en/latest/>

# %% [markdown]
# ## What is `venv`?
#
# > The venv module provides support for creating lightweight “virtual environments” with their own site directories, optionally isolated from system site directories. Each virtual environment has its own Python binary (which matches the version of the binary that was used to create this environment) and can have its own independent set of installed Python packages in its site directories.
#
# Source: <https://docs.python.org/3/library/venv.html>

# %% [markdown]
# ## What is `pip`?
#
# > pip is the package installer for Python. You can use pip to install packages from the Python Package Index and other indexes.
#
# Source: <https://pip.pypa.io/en/stable/>

# %% [markdown]
# ## The pros and cons
#
# - Both `pip` and `venv` are now Python's built-in modules/libraries
# - `conda` can manage both packages and environments

# %% [markdown]
# ## We are gonna use
#
# - `conda` or `venv` as the environment manager depending on previous conditionals
# - `pip` as the package manager

# %% [markdown]
# ## Both package management and environment managements are done in command lines
#
# But if you do want to use it inside a notebook cell, add a `!` to mark it a command rather than a python syntax.
#
# ```python
# # run command in a notebook cell
# !pip --version
# !conda --version
# !python --version
# ```

# %% [markdown]
# ## Commands for multiple versions of Python
#
# - Show the locations of all versions of Python that are currently in the path
#     - Windows: `where python`
#     - Linux, macOS: `which -a python`
# - `python --version` to show version information for the current active Python

# %% [markdown]
# ## Managing environments with `conda`
#
# The basic commands
#
# - `conda info` to verify if `conda` is installed, check version number
# - `conda update conda` to update conda to the current version

# %% [markdown]
# ## Managing environments with `conda`
#
# Commands for environment management
#
# - `conda env list` to get a list of all my environments, active environment is shown with `*`
# - `conda create --name py36 python=3.6` to create a new environment named py36, install Python 3.6
# - `conda activate py36` to activate the environment and use it
# - `conda env remove --name py36` to delete an environment and everything in it
# - `deactivate` to deactivate the current environment

# %% [markdown]
# ## Managing environments with `venv`
#
# The basic commands
#
# - `python -m venv c:/Users/username/pyda` to create a new environment named pyda, install current Python version
# - `c:\Users/username\pyda\Scripts> activate` to activate the environment and use it
# - `(pyda) deactivate` to deactivate the current environment

# %% [markdown]
# ## Managing packages with `pip`
#
# The basic commands
#
# - `pip --version` to verify if `pip` is installed, check version number
# - `pip freeze` to list all modules currently installed
# - `pip show pandas` to show details of `pandas`

# %% [markdown]
# ## Managing packages with `pip`
#
# Commands for package management
#
# - `pip install pandas` to install `pandas` from PyPI
# - `pip install -r requirements.txt` to install all packages listed in requirements.txt
# - `pip uninstall pandas` to uninstall `pandas`

# %% [markdown]
# ## Create a `requirements.txt` listed with with all of our analytical packages
#
# ```
# # requirements.txt
# ipykernel
# numpy==1.18
# pandas==1.0
# xlrd
# PyMySQL
# SQLAlchemy
# ```

# %% [markdown]
# ## Create `pyda` with `conda` and `pip`
#
# ```bash
# (base) pip install jupyter # skip if you use Anaconda
# (base) conda create --name pyda python=3.6.8
# (base) conda activate pyda
# (pyda) pip install -r requirements.txt
# (pyda) python -m ipykernel install --user --name pyda --display-name "Python Data Analysis"
# (pyda) conda deactivate
# (base) jupyter notebook
# ```

# %% [markdown]
# ## Create `pyda` with `venv` and `pip`
#
# Downloading [Python 3.6.8](https://www.python.org/downloads/release/python-368/)

# %% [markdown]
# ## Create `pyda` with `venv` and `pip`
#
# ```bash
# pip install jupyter
# python -m venv c:/Users/username/pyda
# cd c:/Users/username/pyda/Scripts
# activate
# (pyda) pip install -r requirements.txt
# (pyda) python -m ipykernel install --user --name pyda --display-name "Python Data Analysis"
# (pyda) deactivate
# jupyter notebook
# ```

# %% [markdown]
# ## Congrats, now we have a local Python environment for analytical computing!
#
# ![](https://media.giphy.com/media/3o7qDQ4kcSD1PLM3BK/giphy.gif)
#
# Source: <https://giphy.com/>

# %% [markdown]
# ## Essential Data Wrangling Skills in `pandas`

# %% [markdown]
# ## What is `pandas`?
#
# > Flexible and powerful data analysis / manipulation library for Python, providing labeled data structures similar to R data.frame objects, statistical functions, and much more.
#
# Source: <https://github.com/pandas-dev/pandas>

# %% [markdown]
# ## Why `pandas`?
#
# Python used to have a weak spot in its analysis capability due to it did not have an appropriate structure handling the common tabular datasets. Pythonists had to switch to a more data-centric language like R or Matlab during the analysis stage until the presence of `pandas`.

# %% [markdown]
# ## What does `pandas` mean?
#
# ![](https://media.giphy.com/media/46Zj6ze2Z2t4k/giphy.gif)
#
# Source: <https://giphy.com/>

# %% [markdown]
# ## Turns out its naming has nothing to do with panda the animal, it refers to three primary class customed by its author [Wes McKinney](https://wesmckinney.com/)
#
# - **Pan**el(Deprecated since version 0.20.0)
# - **Da**taFrame
# - **S**eries

# %% [markdown]
# ## In order to master `pandas`, it is vital to understand the relationships between `Index`, `ndarray`, `Series`, and `DataFrame`
#
# - An `Index` and a `ndarray` assembles a `Series`
# - A couple of `Series` that sharing the same `Index` can then form a `DataFrame`

# %% [markdown]
# ## Review of the definition of modern data science
#
# > Modern data science is a huge field, it invovles applications and tools like importing, tidying, transformation, visualization, modeling, and communication. Surrounding all these is programming.
#
# ![Imgur](https://i.imgur.com/din6Ig6.png)
#
# Source: [R for Data Science](https://r4ds.had.co.nz/)

# %% [markdown]
# ## Key functionalities analysts rely on `pandas` are
#
# - Importing
# - Tidying
# - Transforming

# %% [markdown]
# ## Tidying and transforming together is also known as WRANGLING
#
# ![](https://media.giphy.com/media/MnlZWRFHR4xruE4N2Z/giphy.gif)
#
# Source: <https://giphy.com/>

# %% [markdown]
# ## Importing

# %% [markdown]
# ## `pandas` has massive functions importing tabular data
#
# - Flat text file
# - Database table
# - Spreadsheet
# - Array of JSONs
# - ...etc.
#
# Source: <https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html>

# %% [markdown]
# ## Using `read_csv` function for flat text files

# %%
from datetime import date
from datetime import timedelta

today = date.today()
day_delta = timedelta(days=-2)
data_date = today + day_delta
print(data_date)
print(type(data_date))
data_date_str = date.strftime(data_date, '%m-%d-%Y')
print(data_date_str)
# Out:
# 2020-06-03
# <class 'datetime.date'>
# 06-03-2020

# %%
daily_report_url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/{}.csv"
daily_report_url = daily_report_url.format(data_date_str)
daily_report = pd.read_csv(daily_report_url)
print(type(daily_report))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Using `read_sql` function for database tables
#
# - Establishing a **connection** via `sqlalchemy`
# - Specifying **MySQL** engine via `pymysql`

# %%
import pymysql
from sqlalchemy import create_engine

host = "ntu-viz-and-ds.ced04jhfjfgi.ap-northeast-1.rds.amazonaws.com"
port = 3306
user = "ntustudent"
passwd = "140112"
conn = create_engine('mysql+pymysql://{}:{}@{}:{}'.format(user, passwd, host, port))

# %%
sql_query = """
SELECT * 
  FROM nba.teams;
"""
nba_teams = pd.read_sql(sql_query, conn)
print(type(nba_teams))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Using `read_excel` function for spreadsheets

# %%
spreadsheet_url = "https://taiwan-election-data.s3-ap-northeast-1.amazonaws.com/presidential_2020/votes-detail-tapei-city.xls"
president_2020_taipei = pd.read_excel(spreadsheet_url)
print(type(president_2020_taipei))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Using `read_json` function for array of JSONs
#
# > JSON (JavaScript Object Notation) is a lightweight data-interchange format. It is easy for humans to read and write. It is easy for machines to parse and generate. It is based on a subset of the JavaScript Programming Language. JSON is a text format that is completely language independent but uses conventions that are familiar to programmers of the C-family of languages, including C, C++, C#, Java, JavaScript, Perl, Python, and many others. These properties make JSON an ideal data-interchange language.
#
# Source: <https://www.json.org/json-en.html>

# %%
import json
import requests

web_api = "https://data.nba.net/prod/v2/2019/teams.json"
resp_dict = requests.get(web_api).json()
teams_dict = resp_dict['league']['standard']
json_str = json.dumps(teams_dict)
with open('teams.json', 'w') as f:
    f.write(json_str)

# %%
teams = pd.read_json("teams.json", orient='records')
print(type(teams))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Basic attributes and methods

# %% [markdown]
# ## Basic attributes of a `DataFrame` object
#
# - `shape`
# - `dtypes`
# - `index`
# - `columns`

# %%
print(daily_report.shape)
print(daily_report.dtypes)
print(daily_report.index)
print(daily_report.columns)
# Out:
# (3644, 14)
# FIPS                   float64
# Admin2                  object
# Province_State          object
# Country_Region          object
# Last_Update             object
# Lat                    float64
# Long_                  float64
# Confirmed                int64
# Deaths                   int64
# Recovered                int64
# Active                   int64
# Combined_Key            object
# Incidence_Rate         float64
# Case-Fatality_Ratio    float64
# dtype: object
# RangeIndex(start=0, stop=3644, step=1)
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incidence_Rate', 'Case-Fatality_Ratio'],
#       dtype='object')

# %% [markdown]
# ## Basic methods of a `DataFrame` object
#
# - `head(n)`
# - `tail(n)`
# - `describe`
# - `info`
# - `set_index`
# - `reset_index`

# %% [markdown]
# ## `head(n)` returns the top n observations with header

# %%
daily_report.head() # n is default to 5
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-06-04 02:33:14
# 1  22001.0     Acadia       Louisiana             US  2020-06-04 02:33:14
# 2  51001.0   Accomack        Virginia             US  2020-06-04 02:33:14
# 3  16001.0        Ada           Idaho             US  2020-06-04 02:33:14
# 4  19001.0      Adair            Iowa             US  2020-06-04 02:33:14
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707         46       0          0      46
# 1  30.295065  -92.414197        446      26          0     420
# 2  37.767072  -75.632346        953      12          0     941
# 3  43.452658 -116.241552        818      22          0     796
# 4  41.330756  -94.471059          9       0          0       9
#
#                     Combined_Key  Incidence_Rate  Case-Fatality_Ratio
# 0  Abbeville, South Carolina, US      187.548416             0.000000
# 1          Acadia, Louisiana, US      718.833105             5.829596
# 2         Accomack, Virginia, US     2949.003590             1.259182
# 3                 Ada, Idaho, US      169.855083             2.689487
# 4                Adair, Iowa, US      125.838926             0.000000

# %% [markdown]
# ## `tail(n)` returns the bottom n observations with header

# %%
daily_report.tail(3)
# Out:
#       FIPS Admin2 Province_State Country_Region          Last_Update  \
# 3641   NaN    NaN            NaN          Yemen  2020-06-04 02:33:14
# 3642   NaN    NaN            NaN         Zambia  2020-06-04 02:33:14
# 3643   NaN    NaN            NaN       Zimbabwe  2020-06-04 02:33:14
#
#             Lat      Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 3641  15.552727  48.516388        419      95         17     307        Yemen
# 3642 -13.133897  27.849332       1089       7        912     170       Zambia
# 3643 -19.015438  29.154857        222       4         29     189     Zimbabwe
#
#       Incidence_Rate  Case-Fatality_Ratio
# 3641        1.404816            22.673031
# 3642        5.923643             0.642792
# 3643        1.493649             1.801802

# %% [markdown]
# ## `describe` returns the descriptive summary for numeric columns

# %%
daily_report.describe()
# Out:
#                FIPS          Lat        Long_      Confirmed        Deaths  \
# count   3027.000000  3572.000000  3572.000000    3644.000000   3644.000000
# mean   31342.109349    36.063272   -73.744682    1786.123765    105.913008
# std    17092.496075    12.746706    51.442183   10995.802465   1033.854829
# min       66.000000   -52.368000  -164.035380       0.000000      0.000000
# 25%    18168.000000    33.626796   -96.175351      15.000000      0.000000
# 50%    29173.000000    37.958375   -87.032254      70.000000      2.000000
# 75%    46060.000000    41.915898   -78.823024     408.750000     13.000000
# max    99999.000000    71.706900   178.065000  279856.000000  39728.000000
#
#            Recovered         Active  Incidence_Rate  Case-Fatality_Ratio
# count    3644.000000    3644.000000     3572.000000          3588.000000
# mean      769.753568     925.917673      315.666515             3.562756
# std     10184.712252   11066.449947      604.770819             5.648357
# min         0.000000 -422920.000000        0.000000             0.000000
# 25%         0.000000      11.000000       55.761671             0.000000
# 50%         0.000000      53.000000      139.318587             1.818182
# 75%         0.000000     290.000000      341.078436             5.263158
# max    479258.000000  240128.000000    12353.775257           130.588235

# %% [markdown]
# ## `info` returns the concise information of the dataframe

# %%
daily_report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3644 entries, 0 to 3643
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FIPS                 3027 non-null   float64
#  1   Admin2               3031 non-null   object
#  2   Province_State       3471 non-null   object
#  3   Country_Region       3644 non-null   object
#  4   Last_Update          3644 non-null   object
#  5   Lat                  3572 non-null   float64
#  6   Long_                3572 non-null   float64
#  7   Confirmed            3644 non-null   int64
#  8   Deaths               3644 non-null   int64
#  9   Recovered            3644 non-null   int64
#  10  Active               3644 non-null   int64
#  11  Combined_Key         3644 non-null   object
#  12  Incidence_Rate       3572 non-null   float64
#  13  Case-Fatality_Ratio  3588 non-null   float64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 398.7+ KB

# %% [markdown]
# ## `set_index` replaces current `Index` with a specific variable

# %%
daily_report.set_index('Combined_Key')
# Out:
#                                   FIPS     Admin2  Province_State  \
# Combined_Key
# Abbeville, South Carolina, US  45001.0  Abbeville  South Carolina
# Acadia, Louisiana, US          22001.0     Acadia       Louisiana
# Accomack, Virginia, US         51001.0   Accomack        Virginia
# Ada, Idaho, US                 16001.0        Ada           Idaho
# Adair, Iowa, US                19001.0      Adair            Iowa
# ...                                ...        ...             ...
# West Bank and Gaza                 NaN        NaN             NaN
# Western Sahara                     NaN        NaN             NaN
# Yemen                              NaN        NaN             NaN
# Zambia                             NaN        NaN             NaN
# Zimbabwe                           NaN        NaN             NaN
#
#                                    Country_Region          Last_Update  \
# Combined_Key
# Abbeville, South Carolina, US                  US  2020-06-04 02:33:14
# Acadia, Louisiana, US                          US  2020-06-04 02:33:14
# Accomack, Virginia, US                         US  2020-06-04 02:33:14
# Ada, Idaho, US                                 US  2020-06-04 02:33:14
# Adair, Iowa, US                                US  2020-06-04 02:33:14
# ...                                           ...                  ...
# West Bank and Gaza             West Bank and Gaza  2020-06-04 02:33:14
# Western Sahara                     Western Sahara  2020-06-04 02:33:14
# Yemen                                       Yemen  2020-06-04 02:33:14
# Zambia                                     Zambia  2020-06-04 02:33:14
# Zimbabwe                                 Zimbabwe  2020-06-04 02:33:14
#
#                                      Lat       Long_  Confirmed  Deaths  \
# Combined_Key
# Abbeville, South Carolina, US  34.223334  -82.461707         46       0
# Acadia, Louisiana, US          30.295065  -92.414197        446      26
# Accomack, Virginia, US         37.767072  -75.632346        953      12
# Ada, Idaho, US                 43.452658 -116.241552        818      22
# Adair, Iowa, US                41.330756  -94.471059          9       0
# ...                                  ...         ...        ...     ...
# West Bank and Gaza             31.952200   35.233200        457       3
# Western Sahara                 24.215500  -12.885800          9       1
# Yemen                          15.552727   48.516388        419      95
# Zambia                        -13.133897   27.849332       1089       7
# Zimbabwe                      -19.015438   29.154857        222       4
#
#                                Recovered  Active  Incidence_Rate  \
# Combined_Key
# Abbeville, South Carolina, US          0      46      187.548416
# Acadia, Louisiana, US                  0     420      718.833105
# Accomack, Virginia, US                 0     941     2949.003590
# Ada, Idaho, US                         0     796      169.855083
# Adair, Iowa, US                        0       9      125.838926
# ...                                  ...     ...             ...
# West Bank and Gaza                   372      82        8.958297
# Western Sahara                         6       2        1.506705
# Yemen                                 17     307        1.404816
# Zambia                               912     170        5.923643
# Zimbabwe                              29     189        1.493649
#
#                                Case-Fatality_Ratio
# Combined_Key
# Abbeville, South Carolina, US             0.000000
# Acadia, Louisiana, US                     5.829596
# Accomack, Virginia, US                    1.259182
# Ada, Idaho, US                            2.689487
# Adair, Iowa, US                           0.000000
# ...                                            ...
# West Bank and Gaza                        0.656455
# Western Sahara                           11.111111
# Yemen                                    22.673031
# Zambia                                    0.642792
# Zimbabwe                                  1.801802
#
# [3644 rows x 13 columns]

# %% [markdown]
# ## `reset_index` resets current `Index` with default `RangeIndex`

# %%
daily_report.set_index('Combined_Key').reset_index()
# Out:
#                        Combined_Key     FIPS     Admin2  Province_State  \
# 0     Abbeville, South Carolina, US  45001.0  Abbeville  South Carolina
# 1             Acadia, Louisiana, US  22001.0     Acadia       Louisiana
# 2            Accomack, Virginia, US  51001.0   Accomack        Virginia
# 3                    Ada, Idaho, US  16001.0        Ada           Idaho
# 4                   Adair, Iowa, US  19001.0      Adair            Iowa
# ...                             ...      ...        ...             ...
# 3639             West Bank and Gaza      NaN        NaN             NaN
# 3640                 Western Sahara      NaN        NaN             NaN
# 3641                          Yemen      NaN        NaN             NaN
# 3642                         Zambia      NaN        NaN             NaN
# 3643                       Zimbabwe      NaN        NaN             NaN
#
#           Country_Region          Last_Update        Lat       Long_  \
# 0                     US  2020-06-04 02:33:14  34.223334  -82.461707
# 1                     US  2020-06-04 02:33:14  30.295065  -92.414197
# 2                     US  2020-06-04 02:33:14  37.767072  -75.632346
# 3                     US  2020-06-04 02:33:14  43.452658 -116.241552
# 4                     US  2020-06-04 02:33:14  41.330756  -94.471059
# ...                  ...                  ...        ...         ...
# 3639  West Bank and Gaza  2020-06-04 02:33:14  31.952200   35.233200
# 3640      Western Sahara  2020-06-04 02:33:14  24.215500  -12.885800
# 3641               Yemen  2020-06-04 02:33:14  15.552727   48.516388
# 3642              Zambia  2020-06-04 02:33:14 -13.133897   27.849332
# 3643            Zimbabwe  2020-06-04 02:33:14 -19.015438   29.154857
#
#       Confirmed  Deaths  Recovered  Active  Incidence_Rate  \
# 0            46       0          0      46      187.548416
# 1           446      26          0     420      718.833105
# 2           953      12          0     941     2949.003590
# 3           818      22          0     796      169.855083
# 4             9       0          0       9      125.838926
# ...         ...     ...        ...     ...             ...
# 3639        457       3        372      82        8.958297
# 3640          9       1          6       2        1.506705
# 3641        419      95         17     307        1.404816
# 3642       1089       7        912     170        5.923643
# 3643        222       4         29     189        1.493649
#
#       Case-Fatality_Ratio
# 0                0.000000
# 1                5.829596
# 2                1.259182
# 3                2.689487
# 4                0.000000
# ...                   ...
# 3639             0.656455
# 3640            11.111111
# 3641            22.673031
# 3642             0.642792
# 3643             1.801802
#
# [3644 rows x 14 columns]

# %% [markdown]
# ## Basic Dataframe Wrangling

# %% [markdown]
# ## Basic wrangling is like writing SQL queries
#
# - Selecting: `SELECT FROM`
# - Filtering: `WHERE`
# - Subsetting: `SELECT FROM WHERE`
# - Indexing
# - Sorting: `ORDER BY`
# - Deriving
# - Summarizing
# - Summarizing and Grouping: `GROUP BY`

# %% [markdown]
# ## Selecting a column as `Series`

# %%
print(daily_report['Country_Region'])
print(type(daily_report['Country_Region']))
# Out:
# 0                       US
# 1                       US
# 2                       US
# 3                       US
# 4                       US
#                ...
# 3639    West Bank and Gaza
# 3640        Western Sahara
# 3641                 Yemen
# 3642                Zambia
# 3643              Zimbabwe
# Name: Country_Region, Length: 3644, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Selecting a column as `DataFrame`

# %%
print(type(daily_report[['Country_Region']]))
daily_report[['Country_Region']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           Country_Region
# 0                     US
# 1                     US
# 2                     US
# 3                     US
# 4                     US
# ...                  ...
# 3639  West Bank and Gaza
# 3640      Western Sahara
# 3641               Yemen
# 3642              Zambia
# 3643            Zimbabwe
#
# [3644 rows x 1 columns]

# %% [markdown]
# ## Selecting multiple columns as `DataFrame`, for sure

# %%
cols = ['Country_Region', 'Province_State']
daily_report[cols]
# Out:
#           Country_Region  Province_State
# 0                     US  South Carolina
# 1                     US       Louisiana
# 2                     US        Virginia
# 3                     US           Idaho
# 4                     US            Iowa
# ...                  ...             ...
# 3639  West Bank and Gaza             NaN
# 3640      Western Sahara             NaN
# 3641               Yemen             NaN
# 3642              Zambia             NaN
# 3643            Zimbabwe             NaN
#
# [3644 rows x 2 columns]

# %% [markdown]
# ## Filtering rows with conditional statements

# %%
is_taiwan = daily_report['Country_Region'] == 'Taiwan*'
daily_report[is_taiwan]
# Out:
#       FIPS Admin2 Province_State Country_Region          Last_Update   Lat  \
# 3623   NaN    NaN            NaN        Taiwan*  2020-06-04 02:33:14  23.7
#
#       Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 3623  121.0        443       7        428       8      Taiwan*
#
#       Incidence_Rate  Case-Fatality_Ratio
# 3623        1.860034             1.580135

# %% [markdown]
# ## Subsetting columns and rows simultaneously

# %%
cols_to_select = ['Country_Region', 'Confirmed']
rows_to_filter = daily_report['Country_Region'] == 'Taiwan*'
daily_report[rows_to_filter][cols_to_select]
# Out:
#      Country_Region  Confirmed
# 3623        Taiwan*        443

# %% [markdown]
# ## Indexing `DataFrame` with
#
# - `loc[]`
# - `iloc[]`

# %% [markdown]
# ## `loc[]` is indexing `DataFrame` with `Index`

# %%
print(daily_report.loc[3388, ['Country_Region', 'Confirmed']]) # as Series
daily_report.loc[[3388], ['Country_Region', 'Confirmed']] # as DataFrame
# Out:
# Country_Region    Japan
# Confirmed            76
# Name: 3388, dtype: object
#      Country_Region  Confirmed
# 3388          Japan         76

# %% [markdown]
# ## `iloc[]` is indexing `DataFrame` with absolute position

# %%
print(daily_report.iloc[3388, [3, 7]]) # as Series
daily_report.iloc[[3388], [3, 7]] # as DataFrame
# Out:
# Country_Region    Japan
# Confirmed            76
# Name: 3388, dtype: object
#      Country_Region  Confirmed
# 3388          Japan         76

# %% [markdown]
# ## Sorting `DataFrame` with
#
# - `sort_values`
# - `sort_index`

# %% [markdown]
# ## `sort_values` sorts `DataFrame` with specific columns

# %%
daily_report.sort_values(['Country_Region', 'Confirmed'])
# Out:
#       FIPS Admin2 Province_State      Country_Region          Last_Update  \
# 3471   NaN    NaN            NaN         Afghanistan  2020-06-04 02:33:14
# 3472   NaN    NaN            NaN             Albania  2020-06-04 02:33:14
# 3473   NaN    NaN            NaN             Algeria  2020-06-04 02:33:14
# 3474   NaN    NaN            NaN             Andorra  2020-06-04 02:33:14
# 3475   NaN    NaN            NaN              Angola  2020-06-04 02:33:14
# ...    ...    ...            ...                 ...                  ...
# 3639   NaN    NaN            NaN  West Bank and Gaza  2020-06-04 02:33:14
# 3640   NaN    NaN            NaN      Western Sahara  2020-06-04 02:33:14
# 3641   NaN    NaN            NaN               Yemen  2020-06-04 02:33:14
# 3642   NaN    NaN            NaN              Zambia  2020-06-04 02:33:14
# 3643   NaN    NaN            NaN            Zimbabwe  2020-06-04 02:33:14
#
#             Lat      Long_  Confirmed  Deaths  Recovered  Active  \
# 3471  33.939110  67.709953      17267     294       1522   15451
# 3472  41.153300  20.168300       1184      33        898     253
# 3473  28.033900   1.659600       9733     673       6218    2842
# 3474  42.506300   1.521800        851      51        735      65
# 3475 -11.202700  17.873900         86       4         18      64
# ...         ...        ...        ...     ...        ...     ...
# 3639  31.952200  35.233200        457       3        372      82
# 3640  24.215500 -12.885800          9       1          6       2
# 3641  15.552727  48.516388        419      95         17     307
# 3642 -13.133897  27.849332       1089       7        912     170
# 3643 -19.015438  29.154857        222       4         29     189
#
#             Combined_Key  Incidence_Rate  Case-Fatality_Ratio
# 3471         Afghanistan       44.355859             1.702670
# 3472             Albania       41.142539             2.787162
# 3473             Algeria       22.195595             6.914620
# 3474             Andorra     1101.404258             5.992949
# 3475              Angola        0.261666             4.651163
# ...                  ...             ...                  ...
# 3639  West Bank and Gaza        8.958297             0.656455
# 3640      Western Sahara        1.506705            11.111111
# 3641               Yemen        1.404816            22.673031
# 3642              Zambia        5.923643             0.642792
# 3643            Zimbabwe        1.493649             1.801802
#
# [3644 rows x 14 columns]

# %% [markdown]
# ## `sort_index` sorts `DataFrame` with the `Index` of `DataFrame`

# %%
daily_report.sort_index(ascending=False)
# Out:
#          FIPS     Admin2  Province_State      Country_Region  \
# 3643      NaN        NaN             NaN            Zimbabwe
# 3642      NaN        NaN             NaN              Zambia
# 3641      NaN        NaN             NaN               Yemen
# 3640      NaN        NaN             NaN      Western Sahara
# 3639      NaN        NaN             NaN  West Bank and Gaza
# ...       ...        ...             ...                 ...
# 4     19001.0      Adair            Iowa                  US
# 3     16001.0        Ada           Idaho                  US
# 2     51001.0   Accomack        Virginia                  US
# 1     22001.0     Acadia       Louisiana                  US
# 0     45001.0  Abbeville  South Carolina                  US
#
#               Last_Update        Lat       Long_  Confirmed  Deaths  \
# 3643  2020-06-04 02:33:14 -19.015438   29.154857        222       4
# 3642  2020-06-04 02:33:14 -13.133897   27.849332       1089       7
# 3641  2020-06-04 02:33:14  15.552727   48.516388        419      95
# 3640  2020-06-04 02:33:14  24.215500  -12.885800          9       1
# 3639  2020-06-04 02:33:14  31.952200   35.233200        457       3
# ...                   ...        ...         ...        ...     ...
# 4     2020-06-04 02:33:14  41.330756  -94.471059          9       0
# 3     2020-06-04 02:33:14  43.452658 -116.241552        818      22
# 2     2020-06-04 02:33:14  37.767072  -75.632346        953      12
# 1     2020-06-04 02:33:14  30.295065  -92.414197        446      26
# 0     2020-06-04 02:33:14  34.223334  -82.461707         46       0
#
#       Recovered  Active                   Combined_Key  Incidence_Rate  \
# 3643         29     189                       Zimbabwe        1.493649
# 3642        912     170                         Zambia        5.923643
# 3641         17     307                          Yemen        1.404816
# 3640          6       2                 Western Sahara        1.506705
# 3639        372      82             West Bank and Gaza        8.958297
# ...         ...     ...                            ...             ...
# 4             0       9                Adair, Iowa, US      125.838926
# 3             0     796                 Ada, Idaho, US      169.855083
# 2             0     941         Accomack, Virginia, US     2949.003590
# 1             0     420          Acadia, Louisiana, US      718.833105
# 0             0      46  Abbeville, South Carolina, US      187.548416
#
#       Case-Fatality_Ratio
# 3643             1.801802
# 3642             0.642792
# 3641            22.673031
# 3640            11.111111
# 3639             0.656455
# ...                   ...
# 4                0.000000
# 3                2.689487
# 2                1.259182
# 1                5.829596
# 0                0.000000
#
# [3644 rows x 14 columns]

# %% [markdown]
# ## Deriving new variables from `DataFrame`
#
# - Simple operations
# - `pd.cut`
# - `map` with a `dict`
# - `map` with a function(or a lambda expression)

# %% [markdown]
# ## Deriving new variable with simple operations

# %%
active = daily_report['Confirmed'] - daily_report['Deaths'] - daily_report['Recovered']
print(active)
# Out:
# 0        46
# 1       420
# 2       941
# 3       796
# 4         9
#        ...
# 3639     82
# 3640      2
# 3641    307
# 3642    170
# 3643    189
# Length: 3644, dtype: int64

# %% [markdown]
# ## Deriving categorical from numerical with `pd.cut`

# %%
import numpy as np

cut_bins = [0, 1000, 10000, 100000, np.Inf]
cut_labels = ['Less than 1000', 'Between 1000 and 10000', 'Between 10000 and 100000', 'Above 100000']
confirmed_categorical = pd.cut(daily_report['Confirmed'], bins=cut_bins, labels=cut_labels, right=False)
print(confirmed_categorical)
# Out:
# 0               Less than 1000
# 1               Less than 1000
# 2               Less than 1000
# 3               Less than 1000
# 4               Less than 1000
#                  ...
# 3639            Less than 1000
# 3640            Less than 1000
# 3641            Less than 1000
# 3642    Between 1000 and 10000
# 3643            Less than 1000
# Name: Confirmed, Length: 3644, dtype: category
# Categories (4, object): [Less than 1000 < Between 1000 and 10000 < Between 10000 and 100000 < Above 100000]

# %% [markdown]
# ## Deriving categorical from categorical with `map`
#
# - Passing a `dict`
# - Passing a function(or lambda expression)

# %%
# Passing a dict
country_name = {
    'Taiwan*': 'Taiwan'
}
daily_report_tw = daily_report[is_taiwan]
daily_report_tw['Country_Region'].map(country_name)
# Out:
# 3623    Taiwan
# Name: Country_Region, dtype: object

# %%
# Passing a function
def is_us(x):
    if x == 'US':
        return 'US'
    else:
        return 'Not US'
daily_report['Country_Region'].map(is_us)
# Out:
# 0           US
# 1           US
# 2           US
# 3           US
# 4           US
#          ...
# 3639    Not US
# 3640    Not US
# 3641    Not US
# 3642    Not US
# 3643    Not US
# Name: Country_Region, Length: 3644, dtype: object

# %%
# Passing a lambda expression)
daily_report['Country_Region'].map(lambda x: 'US' if x == 'US' else 'Not US')
# Out:
# 0           US
# 1           US
# 2           US
# 3           US
# 4           US
#          ...
# 3639    Not US
# 3640    Not US
# 3641    Not US
# 3642    Not US
# 3643    Not US
# Name: Country_Region, Length: 3644, dtype: object

# %% [markdown]
# ## Summarizing `DataFrame` with aggregate methods

# %%
daily_report['Confirmed'].sum()
# Out:
# 6508635

# %% [markdown]
# ## Summarizing and grouping `DataFrame` with aggregate methods

# %%
daily_report.groupby('Country_Region')['Confirmed'].sum()
# Out:
# Country_Region
# Afghanistan           17267
# Albania                1184
# Algeria                9733
# Andorra                 851
# Angola                   86
#                       ...
# West Bank and Gaza      457
# Western Sahara            9
# Yemen                   419
# Zambia                 1089
# Zimbabwe                222
# Name: Confirmed, Length: 188, dtype: int64

# %% [markdown]
# ## More Dataframe Wrangling Operations

# %% [markdown]
# ## Other common `Dataframe` wranglings including
#
# - Dealing with missing values
# - Dealing with text values
# - Reshaping dataframes
# - Merging and joining dataframes

# %% [markdown]
# ## Dealing with missing values
#
# - Using `isnull` or `notnull` to check if `np.NaN` exists
# - Using `dropna` to drop rows with `np.NaN`
# - Using `fillna` to fill `np.NaN` with specific values

# %%
print(daily_report['Province_State'].size)
print(daily_report['Province_State'].isnull().sum())
print(daily_report['Province_State'].notnull().sum())
# Out:
# 3644
# 173
# 3471

# %%
print(daily_report.dropna().shape)
print(daily_report['FIPS'].fillna(0))
# Out:
# (2945, 14)
# 0       45001.0
# 1       22001.0
# 2       51001.0
# 3       16001.0
# 4       19001.0
#          ...
# 3639        0.0
# 3640        0.0
# 3641        0.0
# 3642        0.0
# 3643        0.0
# Name: FIPS, Length: 3644, dtype: float64

# %% [markdown]
# ## Dealing with text values
#
# Prior to `pandas` 1.0, `object` dtype was the only option.

# %%
daily_report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3644 entries, 0 to 3643
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FIPS                 3027 non-null   float64
#  1   Admin2               3031 non-null   object
#  2   Province_State       3471 non-null   object
#  3   Country_Region       3644 non-null   object
#  4   Last_Update          3644 non-null   object
#  5   Lat                  3572 non-null   float64
#  6   Long_                3572 non-null   float64
#  7   Confirmed            3644 non-null   int64
#  8   Deaths               3644 non-null   int64
#  9   Recovered            3644 non-null   int64
#  10  Active               3644 non-null   int64
#  11  Combined_Key         3644 non-null   object
#  12  Incidence_Rate       3572 non-null   float64
#  13  Case-Fatality_Ratio  3588 non-null   float64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 398.7+ KB

# %% [markdown]
# ## Now we can specify `string` to text values

# %%
for col in daily_report.columns:
    if daily_report[col].dtype == 'object':
        daily_report[col] = daily_report[col].astype('string')
daily_report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3644 entries, 0 to 3643
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FIPS                 3027 non-null   float64
#  1   Admin2               3031 non-null   string
#  2   Province_State       3471 non-null   string
#  3   Country_Region       3644 non-null   string
#  4   Last_Update          3644 non-null   string
#  5   Lat                  3572 non-null   float64
#  6   Long_                3572 non-null   float64
#  7   Confirmed            3644 non-null   int64
#  8   Deaths               3644 non-null   int64
#  9   Recovered            3644 non-null   int64
#  10  Active               3644 non-null   int64
#  11  Combined_Key         3644 non-null   string
#  12  Incidence_Rate       3572 non-null   float64
#  13  Case-Fatality_Ratio  3588 non-null   float64
# dtypes: float64(5), int64(4), string(5)
# memory usage: 398.7 KB

# %% [markdown]
# ## Splitting strings with `str.split` as a `Series`

# %%
split_pattern = ', '
daily_report['Combined_Key'].str.split(split_pattern)
# Out:
# 0       [Abbeville, South Carolina, US]
# 1               [Acadia, Louisiana, US]
# 2              [Accomack, Virginia, US]
# 3                      [Ada, Idaho, US]
# 4                     [Adair, Iowa, US]
#                      ...
# 3639               [West Bank and Gaza]
# 3640                   [Western Sahara]
# 3641                            [Yemen]
# 3642                           [Zambia]
# 3643                         [Zimbabwe]
# Name: Combined_Key, Length: 3644, dtype: object

# %% [markdown]
# ## Splitting strings with `str.split` as a `DataFrame`

# %%
split_pattern = ', '
daily_report['Combined_Key'].str.split(split_pattern, expand=True)
# Out:
#                        0               1     2
# 0              Abbeville  South Carolina    US
# 1                 Acadia       Louisiana    US
# 2               Accomack        Virginia    US
# 3                    Ada           Idaho    US
# 4                  Adair            Iowa    US
# ...                  ...             ...   ...
# 3639  West Bank and Gaza            <NA>  <NA>
# 3640      Western Sahara            <NA>  <NA>
# 3641               Yemen            <NA>  <NA>
# 3642              Zambia            <NA>  <NA>
# 3643            Zimbabwe            <NA>  <NA>
#
# [3644 rows x 3 columns]

# %% [markdown]
# ## Along with the new `string` data type, `pd.NA` is introduced

# %%
split_key = daily_report['Combined_Key'].str.split(split_pattern, expand=True)
print(split_key[1][3408] is pd.NA)
# Out:
# False

# %% [markdown]
# ## Replacing strings with `str.replace`

# %%
daily_report['Combined_Key'].str.replace(", ", ';')
# Out:
# 0       Abbeville;South Carolina;US
# 1               Acadia;Louisiana;US
# 2              Accomack;Virginia;US
# 3                      Ada;Idaho;US
# 4                     Adair;Iowa;US
#                    ...
# 3639             West Bank and Gaza
# 3640                 Western Sahara
# 3641                          Yemen
# 3642                         Zambia
# 3643                       Zimbabwe
# Name: Combined_Key, Length: 3644, dtype: string

# %% [markdown]
# ## Testing for strings that match or contain a pattern with `str.contains`

# %%
print(daily_report['Country_Region'].str.contains('land').sum())
daily_report[daily_report['Country_Region'].str.contains('land')]
# Out:
# 12
#       FIPS Admin2                    Province_State Country_Region  \
# 3060   NaN   <NA>                             Aruba    Netherlands
# 3082   NaN   <NA>  Bonaire, Sint Eustatius and Saba    Netherlands
# 3130   NaN   <NA>                           Curacao    Netherlands
# 3392   NaN   <NA>                      Sint Maarten    Netherlands
# 3526   NaN   <NA>                              <NA>        Finland
# 3542   NaN   <NA>                              <NA>        Iceland
# 3547   NaN   <NA>                              <NA>        Ireland
# 3583   NaN   <NA>                              <NA>    Netherlands
# 3584   NaN   <NA>                              <NA>    New Zealand
# 3596   NaN   <NA>                              <NA>         Poland
# 3621   NaN   <NA>                              <NA>    Switzerland
# 3626   NaN   <NA>                              <NA>       Thailand
#
#               Last_Update        Lat       Long_  Confirmed  Deaths  \
# 3060  2020-06-04 02:33:14  12.521100  -69.968300        101       3
# 3082  2020-06-04 02:33:14  12.178400  -68.238500          7       0
# 3130  2020-06-04 02:33:14  12.169600  -68.990000         21       1
# 3392  2020-06-04 02:33:14  18.042500  -63.054800         77      15
# 3526  2020-06-04 02:33:14  61.924110   25.748151       6911     321
# 3542  2020-06-04 02:33:14  64.963100  -19.020800       1806      10
# 3547  2020-06-04 02:33:14  53.142400   -7.692100      25111    1659
# 3583  2020-06-04 02:33:14  52.132600    5.291300      46733    5977
# 3584  2020-06-04 02:33:14 -40.900600  174.886000       1504      22
# 3596  2020-06-04 02:33:14  51.919400   19.145100      24687    1115
# 3621  2020-06-04 02:33:14  46.818200    8.227500      30893    1921
# 3626  2020-06-04 02:33:14  15.870032  100.992541       3084      58
#
#       Recovered  Active                                   Combined_Key  \
# 3060         98       0                             Aruba, Netherlands
# 3082          7       0  Bonaire, Sint Eustatius and Saba, Netherlands
# 3130         15       5                           Curacao, Netherlands
# 3392         60       2                      Sint Maarten, Netherlands
# 3526       5500    1090                                        Finland
# 3542       1794       2                                        Iceland
# 3547      22698     754                                        Ireland
# 3583          0   40756                                    Netherlands
# 3584       1481       1                                    New Zealand
# 3596      12014   11558                                         Poland
# 3621      28600     372                                    Switzerland
# 3626       2968      58                                       Thailand
#
#       Incidence_Rate  Case-Fatality_Ratio
# 3060       94.599404             2.970297
# 3082       26.696160             0.000000
# 3130       12.797075             4.761905
# 3392      179.562520            19.480519
# 3526      124.731127             4.644769
# 3542      529.230769             0.553710
# 3547      508.546728             6.606666
# 3583      272.736191            12.789678
# 3584       31.188870             1.462766
# 3596       65.229100             4.516547
# 3621      356.953941             6.218237
# 3626        4.418340             1.880674

# %% [markdown]
# ## Reshaping dataframes from wide to long format with `pd.melt`
#
# A common problem is that a dataset where some of the column names are not names of variables, but values of a variable.

# %%
ts_confirmed_global_url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
ts_confirmed_global = pd.read_csv(ts_confirmed_global_url)
ts_confirmed_global
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  5/26/20  5/27/20  \
# 0          0        0        0        0        0  ...    11831    12456
# 1          0        0        0        0        0  ...     1029     1050
# 2          0        0        0        0        0  ...     8697     8857
# 3          0        0        0        0        0  ...      763      763
# 4          0        0        0        0        0  ...       70       71
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 261        0        0        0        0        0  ...      441      443
# 262        0        0        0        0        0  ...      249      256
# 263        0        0        0        0        0  ...       87       87
# 264        0        0        0        0        0  ...     3266     3424
# 265        0        0        0        0        0  ...        2        2
#
#      5/28/20  5/29/20  5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  6/4/20
# 0      13036    13659    14525    15205   15750   16509   17267   18054
# 1       1076     1099     1122     1137    1143    1164    1184    1197
# 2       8997     9134     9267     9394    9513    9626    9733    9831
# 3        763      764      764      764     765     844     851     852
# 4         74       81       84       86      86      86      86      86
# ..       ...      ...      ...      ...     ...     ...     ...     ...
# 261      458      463      479      483     484     484     484     485
# 262      278      283      310      323     354     399     419     453
# 263       87       87      106      106     106     132     132     132
# 264     3563     3686     3807     3930    4013    4100    4191    4289
# 265        2        2        2        2       2       2       4       4
#
# [266 rows x 139 columns]

# %% [markdown]
# ## We can pivot the columns into a new pair of variables
#
# To describe that operation we need four parameters:
#
# - The set of columns whose names are not values
# - The set of columns whose names are values
# - The name of the variable to move the column names to
# - The name of the variable to move the column values to

# %% [markdown]
# ## In this example, the four parameters are
#
# - `id_vars`: `['Province/State', 'Country/Region', 'Lat', 'Long']`
# - `value_vars`: The columns from `1/22/20` to the last column
# - `var_name`: Let's name it `Date`
# - `value_name`: Let's name it `Confirmed`

# %%
idVars = ['Province/State', 'Country/Region', 'Lat', 'Long']
ts_confirmed_global_long = pd.melt(ts_confirmed_global,
                                  id_vars=idVars,
                                  var_name='Date',
                                  value_name='Confirmed')
ts_confirmed_global_long
# Out:
#       Province/State         Country/Region        Lat       Long     Date  \
# 0                NaN            Afghanistan  33.000000  65.000000  1/22/20
# 1                NaN                Albania  41.153300  20.168300  1/22/20
# 2                NaN                Algeria  28.033900   1.659600  1/22/20
# 3                NaN                Andorra  42.506300   1.521800  1/22/20
# 4                NaN                 Angola -11.202700  17.873900  1/22/20
# ...              ...                    ...        ...        ...      ...
# 35905            NaN  Sao Tome and Principe   0.186360   6.613081   6/4/20
# 35906            NaN                  Yemen  15.552727  48.516388   6/4/20
# 35907            NaN                Comoros -11.645500  43.333300   6/4/20
# 35908            NaN             Tajikistan  38.861034  71.276093   6/4/20
# 35909            NaN                Lesotho -29.609988  28.233608   6/4/20
#
#        Confirmed
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 35905        485
# 35906        453
# 35907        132
# 35908       4289
# 35909          4
#
# [35910 rows x 6 columns]

# %% [markdown]
# ## Merging and joining dataframes
#
# - `merge` on column names
# - `join` on index

# %% [markdown]
# ## Using `merge` function to join dataframes on columns

# %%
left_df = daily_report[daily_report['Country_Region'].isin(['Taiwan*', 'Japan'])]
right_df = ts_confirmed_global_long[ts_confirmed_global_long['Country/Region'].isin(['Taiwan*', 'Korea, South'])]
# default: inner join
pd.merge(left_df, right_df, left_on='Country_Region', right_on='Country/Region')
# Out:
#      FIPS Admin2 Province_State Country_Region          Last_Update  Lat_x  \
# 0     NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# 1     NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# 2     NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# 3     NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# 4     NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# ..    ...    ...            ...            ...                  ...    ...
# 130   NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# 131   NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# 132   NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# 133   NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# 134   NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
#
#      Long_  Confirmed_x  Deaths  Recovered  Active Combined_Key  \
# 0    121.0          443       7        428       8      Taiwan*
# 1    121.0          443       7        428       8      Taiwan*
# 2    121.0          443       7        428       8      Taiwan*
# 3    121.0          443       7        428       8      Taiwan*
# 4    121.0          443       7        428       8      Taiwan*
# ..     ...          ...     ...        ...     ...          ...
# 130  121.0          443       7        428       8      Taiwan*
# 131  121.0          443       7        428       8      Taiwan*
# 132  121.0          443       7        428       8      Taiwan*
# 133  121.0          443       7        428       8      Taiwan*
# 134  121.0          443       7        428       8      Taiwan*
#
#      Incidence_Rate  Case-Fatality_Ratio Province/State Country/Region  Lat_y  \
# 0          1.860034             1.580135            NaN        Taiwan*   23.7
# 1          1.860034             1.580135            NaN        Taiwan*   23.7
# 2          1.860034             1.580135            NaN        Taiwan*   23.7
# 3          1.860034             1.580135            NaN        Taiwan*   23.7
# 4          1.860034             1.580135            NaN        Taiwan*   23.7
# ..              ...                  ...            ...            ...    ...
# 130        1.860034             1.580135            NaN        Taiwan*   23.7
# 131        1.860034             1.580135            NaN        Taiwan*   23.7
# 132        1.860034             1.580135            NaN        Taiwan*   23.7
# 133        1.860034             1.580135            NaN        Taiwan*   23.7
# 134        1.860034             1.580135            NaN        Taiwan*   23.7
#
#       Long     Date  Confirmed_y
# 0    121.0  1/22/20            1
# 1    121.0  1/23/20            1
# 2    121.0  1/24/20            3
# 3    121.0  1/25/20            3
# 4    121.0  1/26/20            4
# ..     ...      ...          ...
# 130  121.0  5/31/20          442
# 131  121.0   6/1/20          443
# 132  121.0   6/2/20          443
# 133  121.0   6/3/20          443
# 134  121.0   6/4/20          443
#
# [135 rows x 20 columns]

# %%
# left join
pd.merge(left_df, right_df, left_on='Country_Region', right_on='Country/Region', how='left')
# Out:
#      FIPS Admin2 Province_State Country_Region          Last_Update  \
# 0     NaN   <NA>          Aichi          Japan  2020-06-04 02:33:14
# 1     NaN   <NA>          Akita          Japan  2020-06-04 02:33:14
# 2     NaN   <NA>         Aomori          Japan  2020-06-04 02:33:14
# 3     NaN   <NA>          Chiba          Japan  2020-06-04 02:33:14
# 4     NaN   <NA>          Ehime          Japan  2020-06-04 02:33:14
# ..    ...    ...            ...            ...                  ...
# 178   NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14
# 179   NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14
# 180   NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14
# 181   NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14
# 182   NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14
#
#          Lat_x       Long_  Confirmed_x  Deaths  Recovered  Active  \
# 0    35.035551  137.211621          508      34        458      16
# 1    39.748679  140.408228           16       0         16       0
# 2    40.781541  140.828896           27       1         26       0
# 3    35.510141  140.198917          911      45        828      38
# 4    33.624835  132.856842           82       4         59      19
# ..         ...         ...          ...     ...        ...     ...
# 178  23.700000  121.000000          443       7        428       8
# 179  23.700000  121.000000          443       7        428       8
# 180  23.700000  121.000000          443       7        428       8
# 181  23.700000  121.000000          443       7        428       8
# 182  23.700000  121.000000          443       7        428       8
#
#       Combined_Key  Incidence_Rate  Case-Fatality_Ratio Province/State  \
# 0     Aichi, Japan        6.726482             6.692913            NaN
# 1     Akita, Japan        1.655475             0.000000            NaN
# 2    Aomori, Japan        2.166289             3.703704            NaN
# 3     Chiba, Japan       14.554152             4.939627            NaN
# 4     Ehime, Japan        6.122990             4.878049            NaN
# ..             ...             ...                  ...            ...
# 178        Taiwan*        1.860034             1.580135            NaN
# 179        Taiwan*        1.860034             1.580135            NaN
# 180        Taiwan*        1.860034             1.580135            NaN
# 181        Taiwan*        1.860034             1.580135            NaN
# 182        Taiwan*        1.860034             1.580135            NaN
#
#     Country/Region  Lat_y   Long     Date  Confirmed_y
# 0              NaN    NaN    NaN      NaN          NaN
# 1              NaN    NaN    NaN      NaN          NaN
# 2              NaN    NaN    NaN      NaN          NaN
# 3              NaN    NaN    NaN      NaN          NaN
# 4              NaN    NaN    NaN      NaN          NaN
# ..             ...    ...    ...      ...          ...
# 178        Taiwan*   23.7  121.0  5/31/20        442.0
# 179        Taiwan*   23.7  121.0   6/1/20        443.0
# 180        Taiwan*   23.7  121.0   6/2/20        443.0
# 181        Taiwan*   23.7  121.0   6/3/20        443.0
# 182        Taiwan*   23.7  121.0   6/4/20        443.0
#
# [183 rows x 20 columns]

# %%
# right join
pd.merge(left_df, right_df, left_on='Country_Region', right_on='Country/Region', how='right')
# Out:
#      FIPS Admin2 Province_State Country_Region          Last_Update  Lat_x  \
# 0     NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# 1     NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# 2     NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# 3     NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# 4     NaN   <NA>           <NA>        Taiwan*  2020-06-04 02:33:14   23.7
# ..    ...    ...            ...            ...                  ...    ...
# 265   NaN   <NA>           <NA>            NaN                 <NA>    NaN
# 266   NaN   <NA>           <NA>            NaN                 <NA>    NaN
# 267   NaN   <NA>           <NA>            NaN                 <NA>    NaN
# 268   NaN   <NA>           <NA>            NaN                 <NA>    NaN
# 269   NaN   <NA>           <NA>            NaN                 <NA>    NaN
#
#      Long_  Confirmed_x  Deaths  Recovered  Active Combined_Key  \
# 0    121.0        443.0     7.0      428.0     8.0      Taiwan*
# 1    121.0        443.0     7.0      428.0     8.0      Taiwan*
# 2    121.0        443.0     7.0      428.0     8.0      Taiwan*
# 3    121.0        443.0     7.0      428.0     8.0      Taiwan*
# 4    121.0        443.0     7.0      428.0     8.0      Taiwan*
# ..     ...          ...     ...        ...     ...          ...
# 265    NaN          NaN     NaN        NaN     NaN         <NA>
# 266    NaN          NaN     NaN        NaN     NaN         <NA>
# 267    NaN          NaN     NaN        NaN     NaN         <NA>
# 268    NaN          NaN     NaN        NaN     NaN         <NA>
# 269    NaN          NaN     NaN        NaN     NaN         <NA>
#
#      Incidence_Rate  Case-Fatality_Ratio Province/State Country/Region  Lat_y  \
# 0          1.860034             1.580135            NaN        Taiwan*   23.7
# 1          1.860034             1.580135            NaN        Taiwan*   23.7
# 2          1.860034             1.580135            NaN        Taiwan*   23.7
# 3          1.860034             1.580135            NaN        Taiwan*   23.7
# 4          1.860034             1.580135            NaN        Taiwan*   23.7
# ..              ...                  ...            ...            ...    ...
# 265             NaN                  NaN            NaN   Korea, South   36.0
# 266             NaN                  NaN            NaN   Korea, South   36.0
# 267             NaN                  NaN            NaN   Korea, South   36.0
# 268             NaN                  NaN            NaN   Korea, South   36.0
# 269             NaN                  NaN            NaN   Korea, South   36.0
#
#       Long     Date  Confirmed_y
# 0    121.0  1/22/20            1
# 1    121.0  1/23/20            1
# 2    121.0  1/24/20            3
# 3    121.0  1/25/20            3
# 4    121.0  1/26/20            4
# ..     ...      ...          ...
# 265  128.0  5/31/20        11503
# 266  128.0   6/1/20        11541
# 267  128.0   6/2/20        11590
# 268  128.0   6/3/20        11629
# 269  128.0   6/4/20        11668
#
# [270 rows x 20 columns]

# %% [markdown]
# ## Using `join` method to join dataframes on index

# %%
left_df = daily_report[daily_report['Country_Region'].isin(['Taiwan*', 'Japan'])]
right_df = ts_confirmed_global_long[ts_confirmed_global_long['Country/Region'].isin(['Taiwan*', 'Korea, South'])]
left_df = left_df.set_index('Country_Region')
right_df = right_df.set_index('Country/Region')

# %%
# default: left join
left_df.join(right_df, lsuffix='_x', rsuffix='_y')
# Out:
#          FIPS Admin2 Province_State          Last_Update      Lat_x  \
# Japan     NaN   <NA>          Aichi  2020-06-04 02:33:14  35.035551
# Japan     NaN   <NA>          Akita  2020-06-04 02:33:14  39.748679
# Japan     NaN   <NA>         Aomori  2020-06-04 02:33:14  40.781541
# Japan     NaN   <NA>          Chiba  2020-06-04 02:33:14  35.510141
# Japan     NaN   <NA>          Ehime  2020-06-04 02:33:14  33.624835
# ...       ...    ...            ...                  ...        ...
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14  23.700000
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14  23.700000
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14  23.700000
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14  23.700000
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14  23.700000
#
#               Long_  Confirmed_x  Deaths  Recovered  Active   Combined_Key  \
# Japan    137.211621          508      34        458      16   Aichi, Japan
# Japan    140.408228           16       0         16       0   Akita, Japan
# Japan    140.828896           27       1         26       0  Aomori, Japan
# Japan    140.198917          911      45        828      38   Chiba, Japan
# Japan    132.856842           82       4         59      19   Ehime, Japan
# ...             ...          ...     ...        ...     ...            ...
# Taiwan*  121.000000          443       7        428       8        Taiwan*
# Taiwan*  121.000000          443       7        428       8        Taiwan*
# Taiwan*  121.000000          443       7        428       8        Taiwan*
# Taiwan*  121.000000          443       7        428       8        Taiwan*
# Taiwan*  121.000000          443       7        428       8        Taiwan*
#
#          Incidence_Rate  Case-Fatality_Ratio Province/State  Lat_y   Long  \
# Japan          6.726482             6.692913            NaN    NaN    NaN
# Japan          1.655475             0.000000            NaN    NaN    NaN
# Japan          2.166289             3.703704            NaN    NaN    NaN
# Japan         14.554152             4.939627            NaN    NaN    NaN
# Japan          6.122990             4.878049            NaN    NaN    NaN
# ...                 ...                  ...            ...    ...    ...
# Taiwan*        1.860034             1.580135            NaN   23.7  121.0
# Taiwan*        1.860034             1.580135            NaN   23.7  121.0
# Taiwan*        1.860034             1.580135            NaN   23.7  121.0
# Taiwan*        1.860034             1.580135            NaN   23.7  121.0
# Taiwan*        1.860034             1.580135            NaN   23.7  121.0
#
#             Date  Confirmed_y
# Japan        NaN          NaN
# Japan        NaN          NaN
# Japan        NaN          NaN
# Japan        NaN          NaN
# Japan        NaN          NaN
# ...          ...          ...
# Taiwan*  5/31/20        442.0
# Taiwan*   6/1/20        443.0
# Taiwan*   6/2/20        443.0
# Taiwan*   6/3/20        443.0
# Taiwan*   6/4/20        443.0
#
# [183 rows x 18 columns]

# %%
# inner join
left_df.join(right_df, lsuffix='_x', rsuffix='_y', how='inner')
# Out:
#          FIPS Admin2 Province_State          Last_Update  Lat_x  Long_  \
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# ...       ...    ...            ...                  ...    ...    ...
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
#
#          Confirmed_x  Deaths  Recovered  Active Combined_Key  Incidence_Rate  \
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# ...              ...     ...        ...     ...          ...             ...
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
#
#          Case-Fatality_Ratio Province/State  Lat_y   Long     Date  \
# Taiwan*             1.580135            NaN   23.7  121.0  1/22/20
# Taiwan*             1.580135            NaN   23.7  121.0  1/23/20
# Taiwan*             1.580135            NaN   23.7  121.0  1/24/20
# Taiwan*             1.580135            NaN   23.7  121.0  1/25/20
# Taiwan*             1.580135            NaN   23.7  121.0  1/26/20
# ...                      ...            ...    ...    ...      ...
# Taiwan*             1.580135            NaN   23.7  121.0  5/31/20
# Taiwan*             1.580135            NaN   23.7  121.0   6/1/20
# Taiwan*             1.580135            NaN   23.7  121.0   6/2/20
# Taiwan*             1.580135            NaN   23.7  121.0   6/3/20
# Taiwan*             1.580135            NaN   23.7  121.0   6/4/20
#
#          Confirmed_y
# Taiwan*            1
# Taiwan*            1
# Taiwan*            3
# Taiwan*            3
# Taiwan*            4
# ...              ...
# Taiwan*          442
# Taiwan*          443
# Taiwan*          443
# Taiwan*          443
# Taiwan*          443
#
# [135 rows x 18 columns]

# %%
# inner join
left_df.join(right_df, lsuffix='_x', rsuffix='_y', how='inner')
# Out:
#          FIPS Admin2 Province_State          Last_Update  Lat_x  Long_  \
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# ...       ...    ...            ...                  ...    ...    ...
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*   NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
#
#          Confirmed_x  Deaths  Recovered  Active Combined_Key  Incidence_Rate  \
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# ...              ...     ...        ...     ...          ...             ...
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
# Taiwan*          443       7        428       8      Taiwan*        1.860034
#
#          Case-Fatality_Ratio Province/State  Lat_y   Long     Date  \
# Taiwan*             1.580135            NaN   23.7  121.0  1/22/20
# Taiwan*             1.580135            NaN   23.7  121.0  1/23/20
# Taiwan*             1.580135            NaN   23.7  121.0  1/24/20
# Taiwan*             1.580135            NaN   23.7  121.0  1/25/20
# Taiwan*             1.580135            NaN   23.7  121.0  1/26/20
# ...                      ...            ...    ...    ...      ...
# Taiwan*             1.580135            NaN   23.7  121.0  5/31/20
# Taiwan*             1.580135            NaN   23.7  121.0   6/1/20
# Taiwan*             1.580135            NaN   23.7  121.0   6/2/20
# Taiwan*             1.580135            NaN   23.7  121.0   6/3/20
# Taiwan*             1.580135            NaN   23.7  121.0   6/4/20
#
#          Confirmed_y
# Taiwan*            1
# Taiwan*            1
# Taiwan*            3
# Taiwan*            3
# Taiwan*            4
# ...              ...
# Taiwan*          442
# Taiwan*          443
# Taiwan*          443
# Taiwan*          443
# Taiwan*          443
#
# [135 rows x 18 columns]

# %%
# right join
left_df.join(right_df, lsuffix='_x', rsuffix='_y', how='right')
# Out:
#               FIPS Admin2 Province_State          Last_Update  Lat_x  Long_  \
# Korea, South   NaN   <NA>           <NA>                 <NA>    NaN    NaN
# Korea, South   NaN   <NA>           <NA>                 <NA>    NaN    NaN
# Korea, South   NaN   <NA>           <NA>                 <NA>    NaN    NaN
# Korea, South   NaN   <NA>           <NA>                 <NA>    NaN    NaN
# Korea, South   NaN   <NA>           <NA>                 <NA>    NaN    NaN
# ...            ...    ...            ...                  ...    ...    ...
# Taiwan*        NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*        NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*        NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*        NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
# Taiwan*        NaN   <NA>           <NA>  2020-06-04 02:33:14   23.7  121.0
#
#               Confirmed_x  Deaths  Recovered  Active Combined_Key  \
# Korea, South          NaN     NaN        NaN     NaN         <NA>
# Korea, South          NaN     NaN        NaN     NaN         <NA>
# Korea, South          NaN     NaN        NaN     NaN         <NA>
# Korea, South          NaN     NaN        NaN     NaN         <NA>
# Korea, South          NaN     NaN        NaN     NaN         <NA>
# ...                   ...     ...        ...     ...          ...
# Taiwan*             443.0     7.0      428.0     8.0      Taiwan*
# Taiwan*             443.0     7.0      428.0     8.0      Taiwan*
# Taiwan*             443.0     7.0      428.0     8.0      Taiwan*
# Taiwan*             443.0     7.0      428.0     8.0      Taiwan*
# Taiwan*             443.0     7.0      428.0     8.0      Taiwan*
#
#               Incidence_Rate  Case-Fatality_Ratio Province/State  Lat_y  \
# Korea, South             NaN                  NaN            NaN   36.0
# Korea, South             NaN                  NaN            NaN   36.0
# Korea, South             NaN                  NaN            NaN   36.0
# Korea, South             NaN                  NaN            NaN   36.0
# Korea, South             NaN                  NaN            NaN   36.0
# ...                      ...                  ...            ...    ...
# Taiwan*             1.860034             1.580135            NaN   23.7
# Taiwan*             1.860034             1.580135            NaN   23.7
# Taiwan*             1.860034             1.580135            NaN   23.7
# Taiwan*             1.860034             1.580135            NaN   23.7
# Taiwan*             1.860034             1.580135            NaN   23.7
#
#                Long     Date  Confirmed_y
# Korea, South  128.0  1/22/20            1
# Korea, South  128.0  1/23/20            1
# Korea, South  128.0  1/24/20            2
# Korea, South  128.0  1/25/20            2
# Korea, South  128.0  1/26/20            3
# ...             ...      ...          ...
# Taiwan*       121.0  5/31/20          442
# Taiwan*       121.0   6/1/20          443
# Taiwan*       121.0   6/2/20          443
# Taiwan*       121.0   6/3/20          443
# Taiwan*       121.0   6/4/20          443
#
# [270 rows x 18 columns]

# %% [markdown]
# ## Homework 4: From Web API to Dataframes
#
# Upload your `HOMEWORK_4_YOURSTUDENTID.ipynb` file to [CEIBA](https://ceiba.ntu.edu.tw/1082viz_with_ds) before 2020-06-19 03:00:00.

# %% [markdown]
# ## Instructrions
#
# - Sign up at <https://github.com/>, if you already have a GitHub account, skip and move on
# - Go to our [JupyterHub for Homework 4](https://jhub.datainpoint.com/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fyaojenkuo%2Fntu-viz-ds-hw-4&urlpath=tree%2Fntu-viz-ds-hw-4%2FHOMEWORK_4_YOURSTUDENTID.ipynb)
# - Use your GitHub account to sign in

# %% [markdown]
# ## Instructrions for testing
#
# - When you've defined 5 functions, you might want to run some tests
# - Click "Kernel" > "Restart & Run All"

# %% [markdown]
# ## When you've done with testing
#
# Click "File" > "Download as" > "Notebook(.ipynb)" then upload to CEIBA.

# %% [markdown]
# ## Grading Policy
#
# - We will use `df.testing.assert_frame_equal` to evaluate your function outputs
# - Each question accounts for 2%

# %% [markdown]
# ## Question 1
#
# There are m teams in the "Standard League" according to data.nba.net web API <https://data.nba.net/prod/v2/2019/teams.json>. Define a function named `create_standard_teams` which returns a dataframe with the shape of (m, 12).
#
# - Expected input: None
# - Expected output: a (m, 12) DataFrame

# %%
def create_standard_teams():
    """
    >>> create_standard_teams()
    returns a (m, 12) DataFrame
    """
    resp_dict = requests.get("https://data.nba.net/prod/v2/2019/teams.json").json()
    teams_list = resp_dict['league']['standard']
    df = pd.DataFrame()
    for i in teams_list:
        small_df = pd.DataFrame([i])
        df = df.append(small_df)
    df = df.reset_index(drop=True)
    return df

# %%
create_standard_teams()
# Out:
#     isNBAFranchise  isAllStar            city         altCityName  \
# 0            False      False         Croatia             Croatia
# 1            False      False           China               China
# 2            False      False        Adelaide            Adelaide
# 3             True      False         Atlanta             Atlanta
# 4            False       True            Away                Away
# 5            False      False         Beijing             Beijing
# 6             True      False          Boston              Boston
# 7             True      False        Brooklyn            Brooklyn
# 8             True      False       Charlotte           Charlotte
# 9            False      False    Buenos Aires        Buenos Aires
# 10            True      False         Chicago             Chicago
# 11            True      False       Cleveland           Cleveland
# 12            True      False          Dallas              Dallas
# 13            True      False          Denver              Denver
# 14            True      False         Detroit             Detroit
# 15           False      False          Franca              Franca
# 16            True      False    Golden State        Golden State
# 17           False      False       Guangzhou           Guangzhou
# 18           False      False           Haifa               Haifa
# 19           False       True            Home                Home
# 20            True      False         Houston             Houston
# 21            True      False         Indiana             Indiana
# 22            True      False              LA         LA Clippers
# 23            True      False     Los Angeles  Los Angeles Lakers
# 24           False      False       Melbourne           Melbourne
# 25            True      False         Memphis             Memphis
# 26            True      False           Miami               Miami
# 27            True      False       Milwaukee           Milwaukee
# 28            True      False       Minnesota           Minnesota
# 29            True      False     New Orleans         New Orleans
# 30            True      False        New York            New York
# 31           False      False     New Zealand         New Zealand
# 32            True      False   Oklahoma City       Oklahoma City
# 33            True      False         Orlando             Orlando
# 34           False      False           Perth               Perth
# 35            True      False    Philadelphia        Philadelphia
# 36            True      False         Phoenix             Phoenix
# 37            True      False        Portland            Portland
# 38           False      False  Rio de Janeiro      Rio de Janeiro
# 39            True      False      Sacramento          Sacramento
# 40            True      False     San Antonio         San Antonio
# 41           False      False        Shanghai            Shanghai
# 42           False      False          Sydney              Sydney
# 43           False       True            Team                Team
# 44           False       True            Team                Team
# 45           False       True    Team Giannis        Team Giannis
# 46           False       True     Team LeBron         Team LeBron
# 47            True      False         Toronto             Toronto
# 48           False       True             USA                 USA
# 49            True      False            Utah                Utah
# 50            True      False      Washington          Washington
# 51           False       True           World               World
#
#                    fullName tricode      teamId       nickname  \
# 0              Team Croatia     CRO          70        Croatia
# 1                Team China     CHN          45          China
# 2            Adelaide 36ers     ADL       15019          36ers
# 3             Atlanta Hawks     ATL  1610612737          Hawks
# 4                 Away Away     AWY  1610616840           Away
# 5             Beijing Ducks     BJD       15021          Ducks
# 6            Boston Celtics     BOS  1610612738        Celtics
# 7             Brooklyn Nets     BKN  1610612751           Nets
# 8         Charlotte Hornets     CHA  1610612766        Hornets
# 9    San Lorenzo de Almagro     SLA       12330    San Lorenzo
# 10            Chicago Bulls     CHI  1610612741          Bulls
# 11      Cleveland Cavaliers     CLE  1610612739      Cavaliers
# 12         Dallas Mavericks     DAL  1610612742      Mavericks
# 13           Denver Nuggets     DEN  1610612743        Nuggets
# 14          Detroit Pistons     DET  1610612765        Pistons
# 15              SESI/Franca     FRA       12332         Franca
# 16    Golden State Warriors     GSW  1610612744       Warriors
# 17     Guangzhou Long-Lions     GUA       15018     Long-Lions
# 18      Haifa Maccabi Haifa     MAC          93  Maccabi Haifa
# 19                Home Home     HME  1610616839           Home
# 20          Houston Rockets     HOU  1610612745        Rockets
# 21           Indiana Pacers     IND  1610612754         Pacers
# 22              LA Clippers     LAC  1610612746       Clippers
# 23       Los Angeles Lakers     LAL  1610612747         Lakers
# 24         Melbourne United     MEL       15016         United
# 25        Memphis Grizzlies     MEM  1610612763      Grizzlies
# 26               Miami Heat     MIA  1610612748           Heat
# 27          Milwaukee Bucks     MIL  1610612749          Bucks
# 28   Minnesota Timberwolves     MIN  1610612750   Timberwolves
# 29     New Orleans Pelicans     NOP  1610612740       Pelicans
# 30          New York Knicks     NYK  1610612752         Knicks
# 31     New Zealand Breakers     NZB       15020       Breakers
# 32    Oklahoma City Thunder     OKC  1610612760        Thunder
# 33            Orlando Magic     ORL  1610612753          Magic
# 34           Perth Wildcats     PER         104       Wildcats
# 35       Philadelphia 76ers     PHI  1610612755          76ers
# 36             Phoenix Suns     PHX  1610612756           Suns
# 37   Portland Trail Blazers     POR  1610612757  Trail Blazers
# 38  Rio de Janeiro Flamengo     FLA       12325       Flamengo
# 39         Sacramento Kings     SAC  1610612758          Kings
# 40        San Antonio Spurs     SAS  1610612759          Spurs
# 41          Shanghai Sharks     SDS       12329         Sharks
# 42             Sydney Kings     SYD       15015          Kings
# 43                All-Stars     EST  1699999999      All-Stars
# 44                All-Stars     WST  1699999998      All-Stars
# 45             Team Giannis     GNS  1610616833   Team Giannis
# 46              Team LeBron     LBN  1610616834    Team LeBron
# 47          Toronto Raptors     TOR  1610612761        Raptors
# 48                      USA     USA  1610616843            USA
# 49                Utah Jazz     UTA  1610612762           Jazz
# 50       Washington Wizards     WAS  1610612764        Wizards
# 51                    World     WLD  1610616844          World
#
#             urlName  teamShortName confName    divName
# 0           croatia        Croatia   summer
# 1             china          China   summer
# 2             36ers       Adelaide     Intl
# 3             hawks        Atlanta     East  Southeast
# 4              away           Away     East       East
# 5             ducks        Beijing     Intl
# 6           celtics         Boston     East   Atlantic
# 7              nets       Brooklyn     East   Atlantic
# 8           hornets      Charlotte     East  Southeast
# 9       san_lorenzo    San Lorenzo     Intl
# 10            bulls        Chicago     East    Central
# 11        cavaliers      Cleveland     East    Central
# 12        mavericks         Dallas     West  Southwest
# 13          nuggets         Denver     West  Northwest
# 14          pistons        Detroit     East    Central
# 15           franca         Franca     Intl
# 16         warriors   Golden State     West    Pacific
# 17       long-lions      Guangzhou     Intl
# 18    maccabi_haifa  Maccabi Haifa     Intl
# 19             home           Home     East       East
# 20          rockets        Houston     West  Southwest
# 21           pacers        Indiana     East    Central
# 22         clippers    LA Clippers     West    Pacific
# 23           lakers    L.A. Lakers     West    Pacific
# 24           united      Melbourne     Intl
# 25        grizzlies        Memphis     West  Southwest
# 26             heat          Miami     East  Southeast
# 27            bucks      Milwaukee     East    Central
# 28     timberwolves      Minnesota     West  Northwest
# 29         pelicans    New Orleans     West  Southwest
# 30           knicks       New York     East   Atlantic
# 31         breakers    New Zealand     Intl
# 32          thunder  Oklahoma City     West  Northwest
# 33            magic        Orlando     East  Southeast
# 34         wildcats          Perth     Intl
# 35           sixers   Philadelphia     East   Atlantic
# 36             suns        Phoenix     West    Pacific
# 37          blazers       Portland     West  Northwest
# 38         flamengo       Flamengo     Intl
# 39            kings     Sacramento     West    Pacific
# 40            spurs    San Antonio     West  Southwest
# 41  shanghai_sharks       Shanghai     Intl
# 42         sydkings         Sydney     Intl
# 43        assn_away            NaN     East       East
# 44        assn_home            NaN     West       West
# 45     team_giannis   Team Giannis     East       East
# 46      team_lebron    Team LeBron     West       West
# 47          raptors        Toronto     East   Atlantic
# 48              usa            USA     East       East
# 49             jazz           Utah     West  Northwest
# 50          wizards     Washington     East  Southeast
# 51            world          World     East       East

# %% [markdown]
# ## Question 2
#
# There are 30 teams belongs to NBA Franchise among the previous 52 "Standard League" teams. Define a function named `create_nba_teams` which returns a dataframe with the shape of (30, 12).
#
# - Expected input: None
# - Expected output: a (30, 12) DataFrame

# %%
def create_nba_teams():
    """
    >>> create_nba_teams()
    returns a (30, 12) DataFrame
    """
    resp_dict = requests.get("https://data.nba.net/prod/v2/2019/teams.json").json()
    teams_list = resp_dict['league']['standard']
    df = pd.DataFrame()
    for i in teams_list:
        if i['isNBAFranchise']:
            small_df = pd.DataFrame([i])
            df = df.append(small_df)
    df = df.reset_index(drop=True)
    return df

# %%
create_nba_teams()
# Out:
#     isNBAFranchise  isAllStar           city         altCityName  \
# 0             True      False        Atlanta             Atlanta
# 1             True      False         Boston              Boston
# 2             True      False       Brooklyn            Brooklyn
# 3             True      False      Charlotte           Charlotte
# 4             True      False        Chicago             Chicago
# 5             True      False      Cleveland           Cleveland
# 6             True      False         Dallas              Dallas
# 7             True      False         Denver              Denver
# 8             True      False        Detroit             Detroit
# 9             True      False   Golden State        Golden State
# 10            True      False        Houston             Houston
# 11            True      False        Indiana             Indiana
# 12            True      False             LA         LA Clippers
# 13            True      False    Los Angeles  Los Angeles Lakers
# 14            True      False        Memphis             Memphis
# 15            True      False          Miami               Miami
# 16            True      False      Milwaukee           Milwaukee
# 17            True      False      Minnesota           Minnesota
# 18            True      False    New Orleans         New Orleans
# 19            True      False       New York            New York
# 20            True      False  Oklahoma City       Oklahoma City
# 21            True      False        Orlando             Orlando
# 22            True      False   Philadelphia        Philadelphia
# 23            True      False        Phoenix             Phoenix
# 24            True      False       Portland            Portland
# 25            True      False     Sacramento          Sacramento
# 26            True      False    San Antonio         San Antonio
# 27            True      False        Toronto             Toronto
# 28            True      False           Utah                Utah
# 29            True      False     Washington          Washington
#
#                   fullName tricode      teamId       nickname       urlName  \
# 0            Atlanta Hawks     ATL  1610612737          Hawks         hawks
# 1           Boston Celtics     BOS  1610612738        Celtics       celtics
# 2            Brooklyn Nets     BKN  1610612751           Nets          nets
# 3        Charlotte Hornets     CHA  1610612766        Hornets       hornets
# 4            Chicago Bulls     CHI  1610612741          Bulls         bulls
# 5      Cleveland Cavaliers     CLE  1610612739      Cavaliers     cavaliers
# 6         Dallas Mavericks     DAL  1610612742      Mavericks     mavericks
# 7           Denver Nuggets     DEN  1610612743        Nuggets       nuggets
# 8          Detroit Pistons     DET  1610612765        Pistons       pistons
# 9    Golden State Warriors     GSW  1610612744       Warriors      warriors
# 10         Houston Rockets     HOU  1610612745        Rockets       rockets
# 11          Indiana Pacers     IND  1610612754         Pacers        pacers
# 12             LA Clippers     LAC  1610612746       Clippers      clippers
# 13      Los Angeles Lakers     LAL  1610612747         Lakers        lakers
# 14       Memphis Grizzlies     MEM  1610612763      Grizzlies     grizzlies
# 15              Miami Heat     MIA  1610612748           Heat          heat
# 16         Milwaukee Bucks     MIL  1610612749          Bucks         bucks
# 17  Minnesota Timberwolves     MIN  1610612750   Timberwolves  timberwolves
# 18    New Orleans Pelicans     NOP  1610612740       Pelicans      pelicans
# 19         New York Knicks     NYK  1610612752         Knicks        knicks
# 20   Oklahoma City Thunder     OKC  1610612760        Thunder       thunder
# 21           Orlando Magic     ORL  1610612753          Magic         magic
# 22      Philadelphia 76ers     PHI  1610612755          76ers        sixers
# 23            Phoenix Suns     PHX  1610612756           Suns          suns
# 24  Portland Trail Blazers     POR  1610612757  Trail Blazers       blazers
# 25        Sacramento Kings     SAC  1610612758          Kings         kings
# 26       San Antonio Spurs     SAS  1610612759          Spurs         spurs
# 27         Toronto Raptors     TOR  1610612761        Raptors       raptors
# 28               Utah Jazz     UTA  1610612762           Jazz          jazz
# 29      Washington Wizards     WAS  1610612764        Wizards       wizards
#
#     teamShortName confName    divName
# 0         Atlanta     East  Southeast
# 1          Boston     East   Atlantic
# 2        Brooklyn     East   Atlantic
# 3       Charlotte     East  Southeast
# 4         Chicago     East    Central
# 5       Cleveland     East    Central
# 6          Dallas     West  Southwest
# 7          Denver     West  Northwest
# 8         Detroit     East    Central
# 9    Golden State     West    Pacific
# 10        Houston     West  Southwest
# 11        Indiana     East    Central
# 12    LA Clippers     West    Pacific
# 13    L.A. Lakers     West    Pacific
# 14        Memphis     West  Southwest
# 15          Miami     East  Southeast
# 16      Milwaukee     East    Central
# 17      Minnesota     West  Northwest
# 18    New Orleans     West  Southwest
# 19       New York     East   Atlantic
# 20  Oklahoma City     West  Northwest
# 21        Orlando     East  Southeast
# 22   Philadelphia     East   Atlantic
# 23        Phoenix     West    Pacific
# 24       Portland     West  Northwest
# 25     Sacramento     West    Pacific
# 26    San Antonio     West  Southwest
# 27        Toronto     East   Atlantic
# 28           Utah     West  Northwest
# 29     Washington     East  Southeast

# %% [markdown]
# ## Question 3
#
# There are m players in the "Standard League" according to data.nba.net web API <https://data.nba.net/prod/v1/2019/players.json>. Define a function named `create_standard_players` which returns a dataframe with the shape of (m, 15).
#
# - Expected input: None
# - Expected output: a (m, 15) DataFrame

# %%
def create_standard_players():
    """
    >>> create_standard_players()
    returns a (m, 15) DataFrame
    """
    resp_dict = requests.get("https://data.nba.net/prod/v1/2019/players.json").json()
    players_list = resp_dict['league']['standard']
    players_list_dict = []
    for p in players_list:
        player_dict = {}
        for k, v in p.items():
            if isinstance(v, str) or isinstance(v, bool):
                player_dict[k] = v
        players_list_dict.append(player_dict)
    df = pd.DataFrame(players_list_dict)
    selected_df = df.drop(['temporaryDisplayName', 'nbaDebutYear', 'yearsPro', 'lastAffiliation', 'isallStar'], axis=1)
    return selected_df

# %%
create_standard_players()
# Out:
#      firstName          lastName personId      teamId jersey  isActive  pos  \
# 0       Steven             Adams   203500  1610612760     12      True    C
# 1          Bam           Adebayo  1628389  1610612748     13      True  C-F
# 2     LaMarcus          Aldridge   200746  1610612759     12      True  C-F
# 3         Kyle         Alexander  1629734  1610612748     17      True  F-C
# 4      Nickeil  Alexander-Walker  1629638  1610612740      0      True    G
# ..         ...               ...      ...         ...    ...       ...  ...
# 735       Zhun             Zheng    64137                 50     False
# 736        Kun                Si    64139                  6     False
# 737  Ying-Chun              Chen    64140                  2     False
# 738     Dillon             Stith     7020                 52     False
# 739       Tohi      Smith-Milner     7021                 14     False
#
#     heightFeet heightInches heightMeters weightPounds weightKilograms  \
# 0            6           11         2.11          265           120.2
# 1            6            9         2.06          255           115.7
# 2            6           11         2.11          250           113.4
# 3            6           10         2.08          216            98.0
# 4            6            5         1.96          205            93.0
# ..         ...          ...          ...          ...             ...
# 735          -            -
# 736          -            -
# 737          -            -
# 738          -            -
# 739          -            -
#
#     dateOfBirthUTC    collegeName      country
# 0       1993-07-20     Pittsburgh  New Zealand
# 1       1997-07-18       Kentucky          USA
# 2       1985-07-19          Texas          USA
# 3       1996-10-21      Tennessee       Canada
# 4       1998-09-02  Virginia Tech       Canada
# ..             ...            ...          ...
# 735
# 736
# 737
# 738
# 739
#
# [740 rows x 15 columns]

# %% [markdown]
# ## Question 4
#
# There are m players belong to NBA Franchise among the previous "Standard League" players. Define a function named `create_nba_players` which returns a dataframe with the shape of (m, 15).
#
# - Expected input: None
# - Expected output: a (m, 15) DataFrame

# %%
def create_nba_players():
    """
    >>> create_nba_players()
    returns a (m, 15) DataFrame
    """
    resp_dict = requests.get("https://data.nba.net/prod/v1/2019/players.json").json()
    players_list = resp_dict['league']['standard']
    players_list_dict = []
    for p in players_list:
        player_dict = {}
        for k, v in p.items():
            if isinstance(v, str) or isinstance(v, bool):
                player_dict[k] = v
        players_list_dict.append(player_dict)
    df = pd.DataFrame(players_list_dict)
    filtered_df = df[(df['teamId'] != '') & (df['isActive'])]
    selected_df = filtered_df.drop(['temporaryDisplayName', 'nbaDebutYear', 'yearsPro', 'lastAffiliation', 'isallStar'], axis=1)
    selected_df = selected_df.reset_index(drop=True)
    return selected_df

# %%
create_nba_players()
# Out:
#     firstName          lastName personId      teamId jersey  isActive  pos  \
# 0      Steven             Adams   203500  1610612760     12      True    C
# 1         Bam           Adebayo  1628389  1610612748     13      True  C-F
# 2    LaMarcus          Aldridge   200746  1610612759     12      True  C-F
# 3        Kyle         Alexander  1629734  1610612748     17      True  F-C
# 4     Nickeil  Alexander-Walker  1629638  1610612740      0      True    G
# ..        ...               ...      ...         ...    ...       ...  ...
# 492  Thaddeus             Young   201152  1610612741     21      True    F
# 493      Trae             Young  1629027  1610612737     11      True    G
# 494      Cody            Zeller   203469  1610612766     40      True  F-C
# 495      Ante             Zizic  1627790  1610612739     41      True    C
# 496     Ivica             Zubac  1627826  1610612746     40      True    C
#
#     heightFeet heightInches heightMeters weightPounds weightKilograms  \
# 0            6           11         2.11          265           120.2
# 1            6            9         2.06          255           115.7
# 2            6           11         2.11          250           113.4
# 3            6           10         2.08          216            98.0
# 4            6            5         1.96          205            93.0
# ..         ...          ...          ...          ...             ...
# 492          6            8         2.03          235           106.6
# 493          6            1         1.85          180            81.6
# 494          7            0         2.13          240           108.9
# 495          6           10         2.08          266           120.7
# 496          7            0         2.13          240           108.9
#
#     dateOfBirthUTC    collegeName      country
# 0       1993-07-20     Pittsburgh  New Zealand
# 1       1997-07-18       Kentucky          USA
# 2       1985-07-19          Texas          USA
# 3       1996-10-21      Tennessee       Canada
# 4       1998-09-02  Virginia Tech       Canada
# ..             ...            ...          ...
# 492     1988-06-21   Georgia Tech          USA
# 493     1998-09-19       Oklahoma          USA
# 494     1992-10-05        Indiana          USA
# 495     1997-01-04                     Croatia
# 496     1997-03-18                     Croatia
#
# [497 rows x 15 columns]

# %% [markdown]
# ## Question 5
#
# Summarize the nationalities of m active NBA players. Define a function named `count_nba_player_nationalities` which returns a dataframe with the shape of (m, 2), order by number of players with descending order and then country names with ascending order if their counts are the same.
#
# - Expected input: None
# - Expected output: a (m, 2) DataFrame

# %%
def count_nba_player_nationalities():
    """
    >>> count_nba_player_nationalities()
    returns a (m, 2) DataFrame
    """
    resp_dict = requests.get("https://data.nba.net/prod/v1/2019/players.json").json()
    players_list = resp_dict['league']['standard']
    players_list_dict = []
    for p in players_list:
        player_dict = {}
        for k, v in p.items():
            if isinstance(v, str) or isinstance(v, bool):
                player_dict[k] = v
        players_list_dict.append(player_dict)
    df = pd.DataFrame(players_list_dict)
    filtered_df = df[(df['teamId'] != '') & (df['isActive'])]
    ser = filtered_df['country'].value_counts()
    df = pd.DataFrame(ser).reset_index()
    df.columns = ['country', 'player_counts']
    df = df.sort_values(['player_counts', 'country'], ascending=[False, True])
    df = df.reset_index(drop=True)
    return df

# %%
count_nba_player_nationalities()
# Out:
#                              country  player_counts
# 0                                USA            376
# 1                             Canada             20
# 2                             France             11
# 3                          Australia              7
# 4                            Croatia              7
# 5                            Germany              6
# 6                             Serbia              6
# 7                             Latvia              4
# 8                              Spain              4
# 9                             Turkey              4
# 10                            Brazil              3
# 11  Democratic Republic of the Congo              3
# 12                            Greece              3
# 13                             Italy              3
# 14                         Lithuania              3
# 15                          Slovenia              3
# 16                           Bahamas              2
# 17            Bosnia and Herzegovina              2
# 18                          Cameroon              2
# 19                             Japan              2
# 20                           Senegal              2
# 21                             Sudan              2
# 22                       Switzerland              2
# 23                           Ukraine              2
# 24                    United Kingdom              2
# 25                            Angola              1
# 26                           Austria              1
# 27                    Czech Republic              1
# 28                Dominican Republic              1
# 29                             Egypt              1
# 30                           Finland              1
# 31                             Gabon              1
# 32                           Georgia              1
# 33                            Guinea              1
# 34                             Haiti              1
# 35                              Mali              1
# 36                        Montenegro              1
# 37                       New Zealand              1
# 38                           Nigeria              1
# 39                       Puerto Rico              1
# 40                       South Sudan              1

# %% [markdown]
# ## That's all for today, stay healthy and safe :)
